# %% [markdown]
# ##Grants

# %% [markdown]
# ###Permisos de desarrolladores

# %%
# %sql
GRANT USAGE ON SCHEMA catalog_finalproject.bronze TO `DESARROLLADORES`;

# %%
# %sql
GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.bronze.products_bz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.bronze.customers_bz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.bronze.orders_bz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.bronze.sales_bz TO `DESARROLLADORES`;

# %%
# %sql
-- DEVELOPERS
GRANT USAGE ON SCHEMA catalog_finalproject.golden TO `DESARROLLADORES`;
GRANT USAGE ON SCHEMA catalog_finalproject.silver TO `DESARROLLADORES`;

# %%
# %sql
GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.silver.products_sz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.silver.customers_sz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.silver.orders_sz TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.silver.sales_sz TO `DESARROLLADORES`;

# %%
# %sql
GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.golden.dim_date TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.golden.dim_customer TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.golden.dim_product TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.golden.dim_channel TO `DESARROLLADORES`;

GRANT SELECT, MODIFY
ON TABLE catalog_finalproject.golden.fact_sales TO `DESARROLLADORES`;

# %% [markdown]
# ###PERMISOS DE USUARIOS

# %%
# %sql
-- USERS (solo lectura)
GRANT USAGE ON SCHEMA catalog_finalproject.golden TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.golden.fact_sales
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.golden.dim_customer
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.golden.dim_product
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.golden.dim_date
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.golden.dim_channel
TO `USERS`;

# %%
# %sql
GRANT SELECT
ON TABLE catalog_finalproject.silver.products_sz
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.silver.customers_sz
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.silver.orders_sz
TO `USERS`;

GRANT SELECT
ON TABLE catalog_finalproject.silver.sales_sz
TO `USERS`;
